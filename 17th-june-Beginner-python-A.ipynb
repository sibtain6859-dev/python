# %%
age = 21

if age >= 18:
    print('eligible')
else:
    print('not eligible')
# Out:
# eligible

# %%
# Q.1
a = 100

if a > 0:
    print('positive')
elif a ==  0:
    print('zero')
else:
    print('negative')
# Out:
# positive

# %%
# Q. 2
marks = 75

if marks >= 90:
    print('excellent')
elif marks >= 70:
    print('Good')
elif marks >= 40:
    print('average')
else:
    print('fail')
# Out:
# Good

# %%
# Q.4
num = 4

if num == 1:
    print('monday')
elif num == 2:
    print('tuesday')
elif num == 3:
    print('wednesday')
else:
    print('invalid day')
# Out:
# invalid day

# %%
# Q.5
temp = 25

if temp < 15:
    print('cold')
elif 15 < temp <= 30:
    print('warm')
else:
    print('hot')
# Out:
# warm

# %%
# Q.6

letter = 'a'

if letter == 'A':
    print('UPPERCASE')
elif letter == 'a':
    print('LOWERCASE')
else:
    print('digit')
# Out:
# LOWERCASE

# %%
# Q.7

num = 35

if num < 10:
    print('small')
elif 10 < num <= 50:
    print('medium')
else:
    prinnt('large')
# Out:
# medium
